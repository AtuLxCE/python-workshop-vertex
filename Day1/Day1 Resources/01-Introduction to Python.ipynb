# %% [markdown]
# ##                                          What is Python ?
# <img src="https://www.python.org/static/img/python-logo@2x.png" width="300" height="300" />
#
# Python is a general purpose, open source, high-level programming language and also provides number of libraries and frameworks. Python has gained popularity because of its simplicity, easy syntax and user-friendly environment. The usage of Python are as follows.
#
# * Desktop Applications
# * Web Applications
# * Data Science
# * Artificial Intelligence
# * Machine Learning
# * Scientific Computing
# * Robotics
# * Internet of Things (IoT)
# * Gaming
# * Mobile Apps
# * Data Analysis and Preprocessing

# %% [markdown]
# ## History of Python
# <img src="https://gvanrossum.github.io/images/guido-headshot-2019.jpg" width="300" height="300" align="left"/>
#
#
# * Guido van Rossum developed Python in 1991
#
#
# * Emphasizes on Code Readability and Easy to learn
#
#
# * Its syntax allows programmers to express concepts in fewer lines of code.
#
#
# * Two Major Versions of Pythons: Python 2 and Python 3
#
#
# * In this workshop we'll be dealing with Python 3

# %% [markdown]
# ## Python Basics
#
# Let's start by writing a simple **Hello World** Program

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Variables and Data types in Python

# %% [markdown]
# Python is dynamically typed langauge so datatypes are assigned during runtime unlike languages like statically typed langauges like C, C++, etc.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Integers and Floating Point Numbers
#
# So let's start playing with some numbers and perform basic operations

# %%
# Addition
2+2
# Out:
# 4

# %%
# Subtraction
8-4
# Out:
# 4

# %%
# Multiplication
7*2
# Out:
# 14

# %%
# Division
7/4
# Out:
# 1.75

# %%
# Floor Division
7//4
# Out:
# 1

# %%
# Exponentiation
2**3
# Out:
# 8

# %%
# You can do square roots like this
81**0.5
# Out:
# 9.0

# %% [markdown]
# ### Variable Assignment

# %% [markdown]
# #### Rules for variable names
# * names can not start with a number
# * names can not contain spaces, use _ intead
# * names can not contain any of these symbols:
#
#       :'",<>/?|\!@#%^&*~-+
#
# * it's considered best practice ([PEP8](https://www.python.org/dev/peps/pep-0008/#function-and-variable-names)) that names are lowercase with underscores
# * avoid using Python built-in keywords like `list` and `str`
# * avoid using the single characters `l` (lowercase letter el), `O` (uppercase letter oh) and `I` (uppercase letter eye) as they can be confused with `1` and `0`

# %%
# Use single equals to assign values
a = 5

# %%
# Check
a
# Out:
# 5

# %%
# Reassignment
a = 10

# %%
# Check
a
# Out:
# 10

# %%
# use meaningful variable names so others reading your code can understand what's going on
# Use object names to keep better track of what's going on in your code!
my_income = 100

tax_rate = 0.1

my_taxes = my_income*tax_rate

# %%
my_taxes
# Out:
# 10.0

# %% [markdown]
# ## Dynamic Typing
#
# Python uses *dynamic typing*, meaning you can reassign variables to different data types. This makes Python very flexible in assigning data types; it differs from other languages that are *statically typed*.

# %%
# assign an integer value
number = 3

# %% [markdown]
# The **type()** function is a very useful function that returns the type of an object

# %%
type(number)
# Out:
# int

# %%
number = '3'

# %%
type(number)
# Out:
# str

# %%
number = None

# %%
type(number)
# Out:
# NoneType

# %%
number = True

# %%
type(number)
# Out:
# bool

# %%
number = [3, '3', 'three']

# %%
type(number)
# Out:
# list

# %%
number = (3, '3', 'three')

# %%
type(number)
# Out:
# tuple

# %%
number = {'one':1, "two":2, "three": 3}

# %%
type(number)
# Out:
# dict

# %% [markdown]
# So, Let's test what we've learned till now

# %%
# Try to predict the oupyt of the porgram below'
a = 2 + 2 ** 2 * 2
a
# Out:
# 10

# %%
# Now what would be the output of this program
a = (2 + 2) ** (2 * 2)
a
# Out:
# 256

# %%
# Try this one
word = 'Hello'
word*5
# Out:
# 'HelloHelloHelloHelloHello'

# %%
word = word + 'World'
word
# Out:
# 'HelloWorld'

# %%
word = "Wow" + "!" * 5
word
# Out:
# 'Wow!!!!!'

# %% [markdown]
# #### Congratulation ! We've reached our first checkpoint

# %% [markdown]
# ### I/O operations in Python

# %%
# simple program asking input from the user
print('What is your name? ')
name = input()
print('Hello ' + name + ", You're doing great !!")
# Out:
# What is your name?
# Atul
# Hello Atul, You're doing great !!

# %%
# Write a program to ask the User the year he was born and 
# finally calculate his age and display it
print('Enter your year of birth in BS:')
year_of_birth = int(input())
age= 2079-year_of_birth
print('Your age is '+ str(age) + ' years.')
# Out:
# Enter your year of birth in BS:
# 2058
# Your age is 21 years.

# %% [markdown]
# ### Next Up: More about Strings!
